# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MatthewAlexanderFisher/NCL-MAS3919/blob/main/content/practicals/4-online-learning-in-pytorch.ipynb)

# %% [markdown]
# # Online Learning in PyTorch {#sec-practical-online-learning-pytorch} 4-online-learning-in-pytorch
